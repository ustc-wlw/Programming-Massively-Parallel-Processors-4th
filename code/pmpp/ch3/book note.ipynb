# %% [markdown]
# ## ch3 Multidimensional grids and data

# %% [markdown]
# ### A multidimensional example of CUDA grid organization
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Matrix multiplication
#
# P row,col (the small square in P) is the inner product of the vector formed by the rowth row of M (shown as a horizontal strip in M ) and the vector formed by the colth column of N (shown as a vertical strip in N ). The inner product, sometimes called the dot product, of two vectors i the sum of products of the individual vector elements. That is,
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# A matrix multiplication kernel using one thread to compute one P element
#
# ![image.png](attachment:image.png)
