# %% [markdown]
# ## ch1 CPU vs GPU

# %% [markdown]
# CPUs and GPUs have fundamentally different design philosophies
# - CPU design is latency oriented
# - GPU design is throughput-oriented
#
# ![image.png](attachment:image.png)
